# %% [markdown]
# # Markit: recuperation des donnes brutes

# %%
# import des libs
import pandas as pd
import numpy as np
import datetime as dt
from os import *
from os.path import *
import re 
import xlwings as xw
from xlwings import Range

folder_paths = [r"W:\UK\Risk_Control\Risk_Control_Private\MiddleOffice\GPE\Prices\Price Check Tool\Export\Mark-It Raw\2022 05"]

for folder_path in folder_paths:
    onlyfiles = pd.DataFrame([f for f in listdir(folder_path) if isfile(join(folder_path, f))], columns = ["Files"])
    onlyfiles['Date'] = onlyfiles['Files'].apply(lambda x: dt.datetime.strptime(re.search('(\d\d-\d\d-\d\d\d\d)', x).groups()[0], '%d-%m-%Y'))

# %%
onlyfiles
# Out:
#                             Files       Date
# 0   Mark-It Raw - 03-05-2022.xlsx 2022-05-03
# 1   Mark-It Raw - 04-05-2022.xlsx 2022-05-04
# 2   Mark-It Raw - 05-05-2022.xlsx 2022-05-05
# 3   Mark-It Raw - 06-05-2022.xlsx 2022-05-06
# 4   Mark-It Raw - 09-05-2022.xlsx 2022-05-09
# 5   Mark-It Raw - 10-05-2022.xlsx 2022-05-10
# 6   Mark-It Raw - 11-05-2022.xlsx 2022-05-11
# 7   Mark-It Raw - 12-05-2022.xlsx 2022-05-12
# 8   Mark-It Raw - 13-05-2022.xlsx 2022-05-13
# 9   Mark-It Raw - 16-05-2022.xlsx 2022-05-16
# 10  Mark-It Raw - 17-05-2022.xlsx 2022-05-17
# 11  Mark-It Raw - 18-05-2022.xlsx 2022-05-18
# 12  Mark-It Raw - 19-05-2022.xlsx 2022-05-19
# 13  Mark-It Raw - 20-05-2022.xlsx 2022-05-20
# 14  Mark-It Raw - 23-05-2022.xlsx 2022-05-23
# 15  Mark-It Raw - 24-05-2022.xlsx 2022-05-24
# 16  Mark-It Raw - 25-05-2022.xlsx 2022-05-25
# 17  Mark-It Raw - 26-05-2022.xlsx 2022-05-26
# 18  Mark-It Raw - 27-05-2022.xlsx 2022-05-27
# 19  Mark-It Raw - 30-05-2022.xlsx 2022-05-30
# 20  Mark-It Raw - 31-05-2022.xlsx 2022-05-31

# %%
markit_consensus = []

# for each file in the month folder
for index, row in onlyfiles.iterrows():
    print(row['Files'])
    wb = xw.Book(folder_path + '/' + row['Files'], update_links = False)
    ws = wb.sheets('Markit Raw')

# filter data on power   
    num_col = ws.range('A1').end('right').column
    num_row = ws.range('A1').end('down').row
    markit = pd.DataFrame(ws.range((1,1),(num_row,num_col)).value)
    markit.columns = markit.iloc[0]
    markit = markit.iloc[1:]
    markit_consensus.append(markit)
    print('Data collected from' + row['Files'])


markit_consensus = pd.concat(markit_consensus)
markit_consensus = markit_consensus[markit_consensus['ns1:ContractGroup'] == 'European Power']
markit_consensus['ns1:StandardDeviationPrice'].replace('', np.nan, inplace = True)
markit_consensus.dropna(subset = 'ns1:StandardDeviationPrice')
#arkit_consensus.to_csv(r"C:\Users\rmolli\Desktop\Power-Europe\Data Mark-It Raw 05.csv", index = False)
print("travail fait")
markit_consensus
# Out:
# Mark-It Raw - 03-05-2022.xlsx
# Data collected fromMark-It Raw - 03-05-2022.xlsx
# Mark-It Raw - 04-05-2022.xlsx
# Data collected fromMark-It Raw - 04-05-2022.xlsx
# Mark-It Raw - 05-05-2022.xlsx
# Data collected fromMark-It Raw - 05-05-2022.xlsx
# Mark-It Raw - 06-05-2022.xlsx
# Data collected fromMark-It Raw - 06-05-2022.xlsx
# Mark-It Raw - 09-05-2022.xlsx
# Data collected fromMark-It Raw - 09-05-2022.xlsx
# Mark-It Raw - 10-05-2022.xlsx
# Data collected fromMark-It Raw - 10-05-2022.xlsx
# Mark-It Raw - 11-05-2022.xlsx
# Data collected fromMark-It Raw - 11-05-2022.xlsx
# Mark-It Raw - 12-05-2022.xlsx
# Data collected fromMark-It Raw - 12-05-2022.xlsx
# Mark-It Raw - 13-05-2022.xlsx
# Data collected fromMark-It Raw - 13-05-2022.xlsx
# Mark-It Raw - 16-05-2022.xlsx
# Data collected fromMark-It Raw - 16-05-2022.xlsx
# Mark-It Raw - 17-05-2022.xlsx
# Data collected fromMark-It Raw - 17-05-2022.xlsx
# Mark-It Raw - 18-05-2022.xlsx
# Data collected fromMark-It Raw - 18-05-2022.xlsx
# Mark-It Raw - 19-05-2022.xlsx
# Data collected fromMark-It Raw - 19-05-2022.xlsx
# Mark-It Raw - 20-05-2022.xlsx
# Data collected fromMark-It Raw - 20-05-2022.xlsx
# Mark-It Raw - 23-05-2022.xlsx
# Data collected fromMark-It Raw - 23-05-2022.xlsx
# Mark-It Raw - 24-05-2022.xlsx
# Data collected fromMark-It Raw - 24-05-2022.xlsx
# Mark-It Raw - 25-05-2022.xlsx
# Data collected fromMark-It Raw - 25-05-2022.xlsx
# Mark-It Raw - 26-05-2022.xlsx
# Data collected fromMark-It Raw - 26-05-2022.xlsx
# Mark-It Raw - 27-05-2022.xlsx
# Data collected fromMark-It Raw - 27-05-2022.xlsx
# Mark-It Raw - 30-05-2022.xlsx
# Data collected fromMark-It Raw - 30-05-2022.xlsx
# Mark-It Raw - 31-05-2022.xlsx
# Data collected fromMark-It Raw - 31-05-2022.xlsx
# travail fait
# 0    ns1:ClientID    ns1:ValuationDate ns1:AssetClass ns1:ServiceName  \
# 2357        455.0  2022-05-03 00:00:00    Commodities              PG
# 2358        455.0  2022-05-03 00:00:00    Commodities              PG
# 2359        455.0  2022-05-03 00:00:00    Commodities              PG
# 2360        455.0  2022-05-03 00:00:00    Commodities              PG
# 2361        455.0  2022-05-03 00:00:00    Commodities              PG
# ...           ...                  ...            ...             ...
# 5920        455.0  2022-05-31 00:00:00    Commodities              PG
# 5921        455.0  2022-05-31 00:00:00    Commodities              PG
# 5922        455.0  2022-05-31 00:00:00    Commodities              PG
# 5923        455.0  2022-05-31 00:00:00    Commodities              PG
# 5924        455.0  2022-05-31 00:00:00    Commodities              PG
#
# 0    ns1:ServiceFrequency ns1:SubArea ns1:SchemaVersion ns1:ContractGroup  \
# 2357                   DD        10.0              40.0    European Power
# 2358                   DD        10.0              40.0    European Power
# 2359                   DD        10.0              40.0    European Power
# 2360                   DD        10.0              40.0    European Power
# 2361                   DD        10.0              40.0    European Power
# ...                   ...         ...               ...               ...
# 5920                   DD        10.0              40.0    European Power
# 5921                   DD        10.0              40.0    European Power
# 5922                   DD        10.0              40.0    European Power
# 5923                   DD        10.0              40.0    European Power
# 5924                   DD        10.0              40.0    European Power
#
# 0    ns1:Currency ns1:ReferencePublication1  ... ns1:RangePrice  \
# 2357          EUR         PHYSICAL DELIVERY  ...         3.9993
# 2358          EUR         PHYSICAL DELIVERY  ...         5.8517
# 2359          EUR         PHYSICAL DELIVERY  ...         5.8007
# 2360          EUR         PHYSICAL DELIVERY  ...        10.4517
# 2361          EUR         PHYSICAL DELIVERY  ...      10.966527
# ...           ...                       ...  ...            ...
# 5920          GBP         PHYSICAL DELIVERY  ...      44.498227
# 5921          GBP         PHYSICAL DELIVERY  ...      27.342063
# 5922          GBP         PHYSICAL DELIVERY  ...      70.017389
# 5923          GBP         PHYSICAL DELIVERY  ...           None
# 5924          GBP         PHYSICAL DELIVERY  ...           None
#
# 0    ns1:SkewnessPrice ns1:StandardDeviationPrice        ns1:StartDate  \
# 2357          1.407059                    1.40294  2022-06-01 00:00:00
# 2358         -0.429777                   1.895629  2022-07-01 00:00:00
# 2359         -0.484788                   1.948309  2022-08-01 00:00:00
# 2360         -0.071286                   3.216958  2022-09-01 00:00:00
# 2361          0.494116                    3.78331  2022-10-01 00:00:00
# ...                ...                        ...                  ...
# 5920              None                       None  2029-10-01 00:00:00
# 5921              None                       None  2030-04-01 00:00:00
# 5922              None                       None  2030-10-01 00:00:00
# 5923              None                       None  2031-04-01 00:00:00
# 5924              None                       None  2031-10-01 00:00:00
#
# 0    ns1:Units ns1:ClientDistributionBucket ns1:Percentile10Price  \
# 2357       MWH                          4.0                  -5.0
# 2358       MWH                          1.0                 -4.06
# 2359       MWH                          1.0                -6.009
# 2360       MWH                          0.0                 -5.66
# 2361       MWH                          0.0             -8.404086
# ...        ...                          ...                   ...
# 5920       NaN                          NaN                   NaN
# 5921       NaN                          NaN                   NaN
# 5922       NaN                          NaN                   NaN
# 5923       NaN                          NaN                   NaN
# 5924       NaN                          NaN                   NaN
#
# 0    ns1:Percentile90Price ns1:InstrumentType2  \
# 2357               -1.0007             Forward
# 2358                1.7917             Forward
# 2359               -0.2083             Forward
# 2360                4.7917             Forward
# 2361               2.56244             Forward
# ...                    ...                 ...
# 5920                   NaN                 NaN
# 5921                   NaN                 NaN
# 5922                   NaN                 NaN
# 5923                   NaN                 NaN
# 5924                   NaN                 NaN
#
# 0                                         ns1:copyright
# 2357  This document, its contents, the data format a...
# 2358  This document, its contents, the data format a...
# 2359  This document, its contents, the data format a...
# 2360  This document, its contents, the data format a...
# 2361  This document, its contents, the data format a...
# ...                                                 ...
# 5920                                                NaN
# 5921                                                NaN
# 5922                                                NaN
# 5923                                                NaN
# 5924                                                NaN
#
# [74799 rows x 46 columns]

# %%
markit_consensus['ns1:StandardDeviationPrice'].unique()
# Out:
# array([1.40294033, 1.89562901, 1.94830854, ..., 10.36285019, 2.86634909,
#        11.65259509], dtype=object)
