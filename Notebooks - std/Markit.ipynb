# %% [markdown]
# # Markit: recuperation des donnes brutes

# %%
# import des libs
import pandas as pd
import numpy as np
import datetime as dt
from os import *
from os.path import *
import re 
import xlwings as xw
from xlwings import Range

folder_paths = [r"W:\UK\Risk_Control\Risk_Control_Private\MiddleOffice\GPE\Prices\Price Check Tool\Export\Mark-It Raw\2022 08"]

for folder_path in folder_paths:
    onlyfiles = pd.DataFrame([f for f in listdir(folder_path) if isfile(join(folder_path, f))], columns = ["Files"])
    onlyfiles['Date'] = onlyfiles['Files'].apply(lambda x: dt.datetime.strptime(re.search('(\d\d-\d\d-\d\d\d\d)', x).groups()[0], '%d-%m-%Y'))

# %%
markit_consensus = []

# for each file in the month folder
for index, row in onlyfiles.iterrows():
    print(row['Files'])
    wb = xw.Book(folder_path + '/' + row['Files'], update_links = False)
    ws = wb.sheets('Markit Raw')

# filter data on power   
    #num_col = ws.range('A1').end('right').column
    num_row = ws.range('A1').end('down').row
    markit = pd.DataFrame(ws.range((1,1),(num_row,46)).value)
    markit.columns = markit.iloc[0]
    markit = markit.iloc[1:]
    markit_consensus.append(markit)
    print('Data collected from' + row['Files'])


markit_consensus = pd.concat(markit_consensus)
markit_consensus = markit_consensus[markit_consensus['ns1:ContractGroup'] == 'European Power']
markit_consensus['ns1:StandardDeviationPrice'].replace('', np.nan, inplace = True)
markit_consensus.dropna(subset = 'ns1:StandardDeviationPrice')
#markit_consensus.to_csv(r"C:\Users\rmolli\Desktop\Power-Europe\Data Mark-It Raw 07.csv", index = False)
print("travail fait")
markit_consensus
# Out:
# Mark-It Raw - 01-08-2022.xlsx
# Data collected fromMark-It Raw - 01-08-2022.xlsx
# Mark-It Raw - 02-08-2022.xlsx
# Data collected fromMark-It Raw - 02-08-2022.xlsx
# Mark-It Raw - 03-08-2022.xlsx
# Data collected fromMark-It Raw - 03-08-2022.xlsx
# Mark-It Raw - 04-08-2022.xlsx
# Data collected fromMark-It Raw - 04-08-2022.xlsx
# Mark-It Raw - 05-08-2022.xlsx
# Data collected fromMark-It Raw - 05-08-2022.xlsx
# Mark-It Raw - 08-08-2022.xlsx
# Data collected fromMark-It Raw - 08-08-2022.xlsx
# Mark-It Raw - 09-08-2022.xlsx
# Data collected fromMark-It Raw - 09-08-2022.xlsx
# Mark-It Raw - 10-08-2022.xlsx
# Data collected fromMark-It Raw - 10-08-2022.xlsx
# Mark-It Raw - 11-08-2022.xlsx
# Data collected fromMark-It Raw - 11-08-2022.xlsx
# Mark-It Raw - 12-08-2022.xlsx
# Data collected fromMark-It Raw - 12-08-2022.xlsx
# Mark-It Raw - 15-08-2022.xlsx
# Data collected fromMark-It Raw - 15-08-2022.xlsx
# Mark-It Raw - 16-08-2022.xlsx
# Data collected fromMark-It Raw - 16-08-2022.xlsx
# Mark-It Raw - 17-08-2022.xlsx
# Data collected fromMark-It Raw - 17-08-2022.xlsx
# Mark-It Raw - 18-08-2022.xlsx
# Data collected fromMark-It Raw - 18-08-2022.xlsx
# Mark-It Raw - 19-08-2022.xlsx
# Data collected fromMark-It Raw - 19-08-2022.xlsx
# Mark-It Raw - 22-08-2022.xlsx
# Data collected fromMark-It Raw - 22-08-2022.xlsx
# Mark-It Raw - 23-08-2022.xlsx
# Data collected fromMark-It Raw - 23-08-2022.xlsx
# Mark-It Raw - 24-08-2022.xlsx
# Data collected fromMark-It Raw - 24-08-2022.xlsx
# Mark-It Raw - 25-08-2022.xlsx
# Data collected fromMark-It Raw - 25-08-2022.xlsx
# Mark-It Raw - 26-08-2022.xlsx
# Data collected fromMark-It Raw - 26-08-2022.xlsx
# Mark-It Raw - 30-08-2022.xlsx
# Data collected fromMark-It Raw - 30-08-2022.xlsx
# Mark-It Raw - 31-08-2022.xlsx
# Data collected fromMark-It Raw - 31-08-2022.xlsx
# travail fait
# 0    ns1:ClientID    ns1:ValuationDate ns1:AssetClass ns1:ServiceName  \
# 2357        455.0  2022-08-01 00:00:00    Commodities              PG
# 2358        455.0  2022-08-01 00:00:00    Commodities              PG
# 2359        455.0  2022-08-01 00:00:00    Commodities              PG
# 2360        455.0  2022-08-01 00:00:00    Commodities              PG
# 2361        455.0  2022-08-01 00:00:00    Commodities              PG
# ...           ...                  ...            ...             ...
# 6049        455.0  2022-08-31 00:00:00    Commodities              PG
# 6050        455.0  2022-08-31 00:00:00    Commodities              PG
# 6051        455.0  2022-08-31 00:00:00    Commodities              PG
# 6052        455.0  2022-08-31 00:00:00    Commodities              PG
# 6053        455.0  2022-08-31 00:00:00    Commodities              PG
#
# 0    ns1:ServiceFrequency ns1:SubArea ns1:SchemaVersion ns1:ContractGroup  \
# 2357                   DD        10.0              40.0    European Power
# 2358                   DD        10.0              40.0    European Power
# 2359                   DD        10.0              40.0    European Power
# 2360                   DD        10.0              40.0    European Power
# 2361                   DD        10.0              40.0    European Power
# ...                   ...         ...               ...               ...
# 6049                   DD        10.0              40.0    European Power
# 6050                   DD        10.0              40.0    European Power
# 6051                   DD        10.0              40.0    European Power
# 6052                   DD        10.0              40.0    European Power
# 6053                   DD        10.0              40.0    European Power
#
# 0    ns1:Currency ns1:ReferencePublication1  ... ns1:KurtosisPrice  \
# 2357          EUR         PHYSICAL DELIVERY  ...         -1.093595
# 2358          EUR         PHYSICAL DELIVERY  ...         -1.066745
# 2359          EUR         PHYSICAL DELIVERY  ...          0.817916
# 2360          EUR         PHYSICAL DELIVERY  ...          0.536782
# 2361          EUR         PHYSICAL DELIVERY  ...         -1.673784
# ...           ...                       ...  ...               ...
# 6049          GBP         PHYSICAL DELIVERY  ...              None
# 6050          GBP         PHYSICAL DELIVERY  ...              None
# 6051          GBP         PHYSICAL DELIVERY  ...              None
# 6052          GBP         PHYSICAL DELIVERY  ...              None
# 6053          GBP         PHYSICAL DELIVERY  ...              None
#
# 0    ns1:SkewnessPrice ns1:StandardDeviationPrice  \
# 2357          0.200736                   2.759747
# 2358          0.376552                   7.308171
# 2359          1.393423                   8.689461
# 2360         -1.088619                   6.210682
# 2361         -0.387146                    4.80463
# ...                ...                        ...
# 6049              None                       None
# 6050              None                       None
# 6051              None                       None
# 6052              None                       None
# 6053              None                       None
#
# 0    ns1:ClientDistributionBucket ns1:Percentile10Price ns1:Percentile90Price  \
# 2357                         -2.0                   0.0               7.82187
# 2358                          0.0                 -1.29                  21.0
# 2359                         -2.0                   0.0                28.112
# 2360                         -1.0            -10.529121             10.404498
# 2361                         -3.0              -5.63512              6.079041
# ...                           ...                   ...                   ...
# 6049                         None                  None                  None
# 6050                         None                  None                  None
# 6051                         None                  None                  None
# 6052                         None                  None                  None
# 6053                         None                  None                  None
#
# 0    ns1:InstrumentType2                                      ns1:copyright  \
# 2357             Forward  This document, its contents, the data format a...
# 2358             Forward  This document, its contents, the data format a...
# 2359             Forward  This document, its contents, the data format a...
# 2360             Forward  This document, its contents, the data format a...
# 2361             Forward  This document, its contents, the data format a...
# ...                  ...                                                ...
# 6049                None  This document, its contents, the data format a...
# 6050                None  This document, its contents, the data format a...
# 6051                None  This document, its contents, the data format a...
# 6052                None  This document, its contents, the data format a...
# 6053                None  This document, its contents, the data format a...
#
# 0    ns1:CompositeImpliedVolatility ns1:ConsensusImpliedVolatility
# 2357                            NaN                            NaN
# 2358                            NaN                            NaN
# 2359                            NaN                            NaN
# 2360                            NaN                            NaN
# 2361                            NaN                            NaN
# ...                             ...                            ...
# 6049                            NaN                            NaN
# 6050                            NaN                            NaN
# 6051                            NaN                            NaN
# 6052                            NaN                            NaN
# 6053                            NaN                            NaN
#
# [80125 rows x 48 columns]
