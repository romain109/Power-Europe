# %% [markdown]
# # Markit: recuperation des donnes brutes

# %%
# import des libs
import pandas as pd
import numpy as np
import datetime as dt
from os import *
from os.path import *
import re 
import xlwings as xw
from xlwings import Range

folder_paths = [r"W:\UK\Risk_Control\Risk_Control_Private\MiddleOffice\GPE\Prices\Price Check Tool\Export\Mark-It Raw\2022 07"]

for folder_path in folder_paths:
    onlyfiles = pd.DataFrame([f for f in listdir(folder_path) if isfile(join(folder_path, f))], columns = ["Files"])
    onlyfiles['Date'] = onlyfiles['Files'].apply(lambda x: dt.datetime.strptime(re.search('(\d\d-\d\d-\d\d\d\d)', x).groups()[0], '%d-%m-%Y'))

# %%
o = onlyfiles[1:2]
o
# Out:
#                            Files       Date
# 1  Mark-It Raw - 04-07-2022.xlsx 2022-07-04

# %%
markit_consensus = []

# for each file in the month folder
for index, row in onlyfiles.iterrows():
    print(row['Files'])
    wb = xw.Book(folder_path + '/' + row['Files'], update_links = False)
    ws = wb.sheets('Markit Raw')

# filter data on power   
    #num_col = ws.range('A1').end('right').column
    num_row = ws.range('A1').end('down').row
    markit = pd.DataFrame(ws.range((1,1),(num_row,46)).value)
    markit.columns = markit.iloc[0]
    markit = markit.iloc[1:]
    markit_consensus.append(markit)
    print('Data collected from' + row['Files'])


markit_consensus = pd.concat(markit_consensus)
markit_consensus = markit_consensus[markit_consensus['ns1:ContractGroup'] == 'European Power']
markit_consensus['ns1:StandardDeviationPrice'].replace('', np.nan, inplace = True)
#markit_consensus.dropna(subset = 'ns1:StandardDeviationPrice')
markit_consensus.to_csv(r"C:\Users\rmolli\Desktop\Power-Europe\Data Mark-It Raw 07.csv", index = False)
print("travail fait")
markit_consensus
# Out:
# Mark-It Raw - 01-07-2022.xlsx
# Data collected fromMark-It Raw - 01-07-2022.xlsx
# Mark-It Raw - 04-07-2022.xlsx
# Data collected fromMark-It Raw - 04-07-2022.xlsx
# Mark-It Raw - 05-07-2022.xlsx
# Data collected fromMark-It Raw - 05-07-2022.xlsx
# Mark-It Raw - 06-07-2022.xlsx
# Data collected fromMark-It Raw - 06-07-2022.xlsx
# Mark-It Raw - 07-07-2022.xlsx
# Data collected fromMark-It Raw - 07-07-2022.xlsx
# Mark-It Raw - 08-07-2022.xlsx
# Data collected fromMark-It Raw - 08-07-2022.xlsx
# Mark-It Raw - 11-07-2022.xlsx
# Data collected fromMark-It Raw - 11-07-2022.xlsx
# Mark-It Raw - 12-07-2022.xlsx
# Data collected fromMark-It Raw - 12-07-2022.xlsx
# Mark-It Raw - 13-07-2022.xlsx
# Data collected fromMark-It Raw - 13-07-2022.xlsx
# Mark-It Raw - 14-07-2022.xlsx
# Data collected fromMark-It Raw - 14-07-2022.xlsx
# Mark-It Raw - 15-07-2022.xlsx
# Data collected fromMark-It Raw - 15-07-2022.xlsx
# Mark-It Raw - 18-07-2022.xlsx
# Data collected fromMark-It Raw - 18-07-2022.xlsx
# Mark-It Raw - 19-07-2022.xlsx
# Data collected fromMark-It Raw - 19-07-2022.xlsx
# Mark-It Raw - 20-07-2022.xlsx
# Data collected fromMark-It Raw - 20-07-2022.xlsx
# Mark-It Raw - 21-07-2022.xlsx
# Data collected fromMark-It Raw - 21-07-2022.xlsx
# Mark-It Raw - 22-07-2022.xlsx
# Data collected fromMark-It Raw - 22-07-2022.xlsx
# Mark-It Raw - 25-07-2022.xlsx
# Data collected fromMark-It Raw - 25-07-2022.xlsx
# Mark-It Raw - 26-07-2022.xlsx
# Data collected fromMark-It Raw - 26-07-2022.xlsx
# Mark-It Raw - 27-07-2022.xlsx
# Data collected fromMark-It Raw - 27-07-2022.xlsx
# Mark-It Raw - 28-07-2022.xlsx
# Data collected fromMark-It Raw - 28-07-2022.xlsx
# Mark-It Raw - 29-07-2022.xlsx
# Data collected fromMark-It Raw - 29-07-2022.xlsx
# travail fait
# 0    ns1:ClientID    ns1:ValuationDate ns1:AssetClass ns1:ServiceName  \
# 2329        455.0  2022-07-01 00:00:00    Commodities              PG
# 2330        455.0  2022-07-01 00:00:00    Commodities              PG
# 2331        455.0  2022-07-01 00:00:00    Commodities              PG
# 2332        455.0  2022-07-01 00:00:00    Commodities              PG
# 2333        455.0  2022-07-01 00:00:00    Commodities              PG
# ...           ...                  ...            ...             ...
# 6057        455.0  2022-07-29 00:00:00    Commodities              PG
# 6058        455.0  2022-07-29 00:00:00    Commodities              PG
# 6059        455.0  2022-07-29 00:00:00    Commodities              PG
# 6060        455.0  2022-07-29 00:00:00    Commodities              PG
# 6061        455.0  2022-07-29 00:00:00    Commodities              PG
#
# 0    ns1:ServiceFrequency ns1:SubArea ns1:SchemaVersion ns1:ContractGroup  \
# 2329                   DD        10.0              40.0    European Power
# 2330                   DD        10.0              40.0    European Power
# 2331                   DD        10.0              40.0    European Power
# 2332                   DD        10.0              40.0    European Power
# 2333                   DD        10.0              40.0    European Power
# ...                   ...         ...               ...               ...
# 6057                   DD        10.0              40.0    European Power
# 6058                   DD        10.0              40.0    European Power
# 6059                   DD        10.0              40.0    European Power
# 6060                   DD        10.0              40.0    European Power
# 6061                   DD        10.0              40.0    European Power
#
# 0    ns1:Currency ns1:ReferencePublication1  ... ns1:RangePrice  \
# 2329          EUR         PHYSICAL DELIVERY  ...            5.0
# 2330          EUR         PHYSICAL DELIVERY  ...        6.49968
# 2331          EUR         PHYSICAL DELIVERY  ...        30.9525
# 2332          EUR         PHYSICAL DELIVERY  ...          17.42
# 2333          EUR         PHYSICAL DELIVERY  ...        18.4851
# ...           ...                       ...  ...            ...
# 6057          GBP         PHYSICAL DELIVERY  ...      19.634982
# 6058          GBP         PHYSICAL DELIVERY  ...      17.072921
# 6059          GBP         PHYSICAL DELIVERY  ...      27.135028
# 6060          GBP         PHYSICAL DELIVERY  ...           None
# 6061          GBP         PHYSICAL DELIVERY  ...           None
#
# 0    ns1:SkewnessPrice ns1:StandardDeviationPrice        ns1:StartDate  \
# 2329           0.31669                   1.823543  2022-08-01 00:00:00
# 2330         -0.491115                   1.904612  2022-09-01 00:00:00
# 2331          0.100732                   7.977761  2022-10-01 00:00:00
# 2332         -0.096793                    4.80997  2022-11-01 00:00:00
# 2333          0.534638                   4.693925  2022-12-01 00:00:00
# ...                ...                        ...                  ...
# 6057              None                       None  2029-10-01 00:00:00
# 6058              None                       None  2030-04-01 00:00:00
# 6059              None                       None  2030-10-01 00:00:00
# 6060              None                       None  2031-04-01 00:00:00
# 6061              None                       None  2031-10-01 00:00:00
#
# 0    ns1:Units ns1:ClientDistributionBucket ns1:Percentile10Price  \
# 2329       MWH                          2.0                   5.0
# 2330       MWH                          2.0                  -3.5
# 2331       MWH                          0.0              -18.4525
# 2332       MWH                          0.0                 -13.0
# 2333       MWH                          1.0               -8.9651
# ...        ...                          ...                   ...
# 6057       MWH                         None                  None
# 6058       MWH                         None                  None
# 6059       MWH                         None                  None
# 6060       MWH                         None                  None
# 6061       MWH                         None                  None
#
# 0    ns1:Percentile90Price ns1:InstrumentType2  \
# 2329                  10.0             Forward
# 2330               2.99968             Forward
# 2331                  12.5             Forward
# 2332                  4.42             Forward
# 2333                  9.52             Forward
# ...                    ...                 ...
# 6057                  None                None
# 6058                  None                None
# 6059                  None                None
# 6060                  None                None
# 6061                  None                None
#
# 0                                         ns1:copyright
# 2329  This document, its contents, the data format a...
# 2330  This document, its contents, the data format a...
# 2331  This document, its contents, the data format a...
# 2332  This document, its contents, the data format a...
# 2333  This document, its contents, the data format a...
# ...                                                 ...
# 6057  This document, its contents, the data format a...
# 6058  This document, its contents, the data format a...
# 6059  This document, its contents, the data format a...
# 6060  This document, its contents, the data format a...
# 6061  This document, its contents, the data format a...
#
# [72059 rows x 46 columns]

# %%
markit_consensus.columns
# Out:
# Index(['ns1:ClientID', 'ns1:ValuationDate', 'ns1:AssetClass',
#        'ns1:ServiceName', 'ns1:ServiceFrequency', 'ns1:SubArea',
#        'ns1:SchemaVersion', 'ns1:ContractGroup', 'ns1:Currency',
#        'ns1:ReferencePublication1', 'ns1:ReferencePublication2',
#        'ns1:Underlying', 'ns1:Underlying1', 'ns1:Underlying2', 'ns1:CCYScalar',
#        'ns1:ClientPrice', 'ns1:CompositePrice', 'ns1:ConsensusPrice',
#        'ns1:DistributionMinus4', 'ns1:DistributionMinus3',
#        'ns1:DistributionMinus2', 'ns1:DistributionMinus1', 'ns1:Distribution0',
#        'ns1:DistributionPlus1', 'ns1:DistributionPlus2',
#        'ns1:DistributionPlus3', 'ns1:DistributionPlus4', 'ns1:EndDate',
#        'ns1:InstrumentType', 'ns1:InstrumentType1', 'ns1:IsImplied',
#        'ns1:KnockoutPrice', 'ns1:KurtosisPrice', 'ns1:NumberAcceptedPrice',
#        'ns1:Period', 'ns1:PricingTime', 'ns1:RangePrice', 'ns1:SkewnessPrice',
#        'ns1:StandardDeviationPrice', 'ns1:StartDate', 'ns1:Units',
#        'ns1:ClientDistributionBucket', 'ns1:Percentile10Price',
#        'ns1:Percentile90Price', 'ns1:InstrumentType2', 'ns1:copyright'],
#       dtype='object', name=0)

# %%
markit_consensus.columns
# Out:
# Index(['ns1:ClientID', 'ns1:ValuationDate', 'ns1:AssetClass',
#        'ns1:ServiceName', 'ns1:ServiceFrequency', 'ns1:SubArea',
#        'ns1:SchemaVersion', 'ns1:ContractGroup', 'ns1:Currency',
#        'ns1:ReferencePublication1', 'ns1:ReferencePublication2',
#        'ns1:Underlying', 'ns1:Underlying1', 'ns1:Underlying2', 'ns1:CCYScalar',
#        'ns1:ClientPrice', 'ns1:CompositePrice', 'ns1:ConsensusPrice',
#        'ns1:DistributionMinus4', 'ns1:DistributionMinus3',
#        'ns1:DistributionMinus2', 'ns1:DistributionMinus1', 'ns1:Distribution0',
#        'ns1:DistributionPlus1', 'ns1:DistributionPlus2',
#        'ns1:DistributionPlus3', 'ns1:DistributionPlus4', 'ns1:EndDate',
#        'ns1:InstrumentType', 'ns1:InstrumentType1', 'ns1:IsImplied',
#        'ns1:KnockoutPrice', 'ns1:KurtosisPrice', 'ns1:NumberAcceptedPrice',
#        'ns1:Period', 'ns1:PricingTime', 'ns1:RangePrice', 'ns1:SkewnessPrice',
#        'ns1:StandardDeviationPrice', 'ns1:StartDate', 'ns1:Units',
#        'ns1:ClientDistributionBucket', 'ns1:Percentile10Price',
#        'ns1:Percentile90Price', 'ns1:InstrumentType2', 'ns1:copyright'],
#       dtype='object', name=0)
