# %% [markdown]
# # Markit: recuperation des donnes brutes

# %%
# import des libs
import pandas as pd
import numpy as np
import datetime as dt
from os import *
from os.path import *
import re 
import xlwings as xw
from xlwings import Range

folder_paths = [r"W:\UK\Risk_Control\Risk_Control_Private\MiddleOffice\GPE\Prices\Price Check Tool\Export\Mark-It Raw\2022 09"]

for folder_path in folder_paths:
    onlyfiles = pd.DataFrame([f for f in listdir(folder_path) if isfile(join(folder_path, f))], columns = ["Files"])
    onlyfiles['Date'] = onlyfiles['Files'].apply(lambda x: dt.datetime.strptime(re.search('(\d\d-\d\d-\d\d\d\d)', x).groups()[0], '%d-%m-%Y'))

# %%
onlyfiles
# Out:
#                             Files       Date
# 0   Mark-It Raw - 01-09-2022.xlsx 2022-09-01
# 1   Mark-It Raw - 02-09-2022.xlsx 2022-09-02
# 2   Mark-It Raw - 06-09-2022.xlsx 2022-09-06
# 3   Mark-It Raw - 07-09-2022.xlsx 2022-09-07
# 4   Mark-It Raw - 08-09-2022.xlsx 2022-09-08
# 5   Mark-It Raw - 09-09-2022.xlsx 2022-09-09
# 6   Mark-It Raw - 12-09-2022.xlsx 2022-09-12
# 7   Mark-It Raw - 13-09-2022.xlsx 2022-09-13
# 8   Mark-It Raw - 14-09-2022.xlsx 2022-09-14
# 9   Mark-It Raw - 15-09-2022.xlsx 2022-09-15
# 10  Mark-It Raw - 16-09-2022.xlsx 2022-09-16
# 11  Mark-It Raw - 19-09-2022.xlsx 2022-09-19
# 12  Mark-It Raw - 20-09-2022.xlsx 2022-09-20
# 13  Mark-It Raw - 21-09-2022.xlsx 2022-09-21
# 14  Mark-It Raw - 22-09-2022.xlsx 2022-09-22
# 15  Mark-It Raw - 23-09-2022.xlsx 2022-09-23
# 16  Mark-It Raw - 26-09-2022.xlsx 2022-09-26

# %%
markit_consensus = []

# for each file in the month folder
for index, row in onlyfiles.iterrows():
    print(row['Files'])
    wb = xw.Book(folder_path + '/' + row['Files'], update_links = False)
    ws = wb.sheets('Markit Raw')

# filter data on power   
    #num_col = ws.range('A1').end('right').column
    num_row = ws.range('A1').end('down').row
    markit = pd.DataFrame(ws.range((1,1),(num_row,46)).value)
    markit.columns = markit.iloc[0]
    markit = markit.iloc[1:]
    markit_consensus.append(markit)
    print('Data collected from' + row['Files'])


markit_consensus = pd.concat(markit_consensus)
markit_consensus = markit_consensus[markit_consensus['ns1:ContractGroup'] == 'European Power']
markit_consensus['ns1:StandardDeviationPrice'].replace('', np.nan, inplace = True)
markit_consensus.dropna(subset = 'ns1:StandardDeviationPrice')
#markit_consensus.to_csv(r"C:\Users\rmolli\Desktop\Power-Europe\Data Mark-It Raw 07.csv", index = False)
print("travail fait")
markit_consensus
# Out:
# Mark-It Raw - 01-09-2022.xlsx
# Data collected fromMark-It Raw - 01-09-2022.xlsx
# Mark-It Raw - 02-09-2022.xlsx
# Data collected fromMark-It Raw - 02-09-2022.xlsx
# Mark-It Raw - 06-09-2022.xlsx
# Data collected fromMark-It Raw - 06-09-2022.xlsx
# Mark-It Raw - 07-09-2022.xlsx
# Data collected fromMark-It Raw - 07-09-2022.xlsx
# Mark-It Raw - 08-09-2022.xlsx
# Data collected fromMark-It Raw - 08-09-2022.xlsx
# Mark-It Raw - 09-09-2022.xlsx
# Data collected fromMark-It Raw - 09-09-2022.xlsx
# Mark-It Raw - 12-09-2022.xlsx
# Data collected fromMark-It Raw - 12-09-2022.xlsx
# Mark-It Raw - 13-09-2022.xlsx
# Data collected fromMark-It Raw - 13-09-2022.xlsx
# Mark-It Raw - 14-09-2022.xlsx
# Data collected fromMark-It Raw - 14-09-2022.xlsx
# Mark-It Raw - 15-09-2022.xlsx
# Data collected fromMark-It Raw - 15-09-2022.xlsx
# Mark-It Raw - 16-09-2022.xlsx
# Data collected fromMark-It Raw - 16-09-2022.xlsx
# Mark-It Raw - 19-09-2022.xlsx
# Data collected fromMark-It Raw - 19-09-2022.xlsx
# Mark-It Raw - 20-09-2022.xlsx
# Data collected fromMark-It Raw - 20-09-2022.xlsx
# Mark-It Raw - 21-09-2022.xlsx
# Data collected fromMark-It Raw - 21-09-2022.xlsx
# Mark-It Raw - 22-09-2022.xlsx
# Data collected fromMark-It Raw - 22-09-2022.xlsx
# Mark-It Raw - 23-09-2022.xlsx
# Data collected fromMark-It Raw - 23-09-2022.xlsx
# Mark-It Raw - 26-09-2022.xlsx
# Data collected fromMark-It Raw - 26-09-2022.xlsx
# travail fait
# 0    ns1:ClientID    ns1:ValuationDate ns1:AssetClass ns1:ServiceName  \
# 2319        455.0  2022-09-01 00:00:00    Commodities              PG
# 2320        455.0  2022-09-01 00:00:00    Commodities              PG
# 2321        455.0  2022-09-01 00:00:00    Commodities              PG
# 2322        455.0  2022-09-01 00:00:00    Commodities              PG
# 2323        455.0  2022-09-01 00:00:00    Commodities              PG
# ...           ...                  ...            ...             ...
# 6032        455.0  2022-09-26 00:00:00    Commodities              PG
# 6033        455.0  2022-09-26 00:00:00    Commodities              PG
# 6034        455.0  2022-09-26 00:00:00    Commodities              PG
# 6035        455.0  2022-09-26 00:00:00    Commodities              PG
# 6036        455.0  2022-09-26 00:00:00    Commodities              PG
#
# 0    ns1:ServiceFrequency ns1:SubArea ns1:SchemaVersion ns1:ContractGroup  \
# 2319                   DD        10.0              40.0    European Power
# 2320                   DD        10.0              40.0    European Power
# 2321                   DD        10.0              40.0    European Power
# 2322                   DD        10.0              40.0    European Power
# 2323                   DD        10.0              40.0    European Power
# ...                   ...         ...               ...               ...
# 6032                   DD        10.0              40.0    European Power
# 6033                   DD        10.0              40.0    European Power
# 6034                   DD        10.0              40.0    European Power
# 6035                   DD        10.0              40.0    European Power
# 6036                   DD        10.0              40.0    European Power
#
# 0    ns1:Currency ns1:ReferencePublication1  ... ns1:DistributionPlus3  \
# 2319          EUR         PHYSICAL DELIVERY  ...                   2.0
# 2320          EUR         PHYSICAL DELIVERY  ...                   1.0
# 2321          EUR         PHYSICAL DELIVERY  ...                   1.0
# 2322          EUR         PHYSICAL DELIVERY  ...                   0.0
# 2323          EUR         PHYSICAL DELIVERY  ...                   0.0
# ...           ...                       ...  ...                   ...
# 6032          GBP         PHYSICAL DELIVERY  ...                  None
# 6033          GBP         PHYSICAL DELIVERY  ...                  None
# 6034          GBP         PHYSICAL DELIVERY  ...                  None
# 6035          GBP         PHYSICAL DELIVERY  ...                  None
# 6036          GBP         PHYSICAL DELIVERY  ...                  None
#
# 0    ns1:DistributionPlus4 ns1:KurtosisPrice ns1:SkewnessPrice  \
# 2319                   0.0          -0.98985          0.511067
# 2320                   1.0         -0.262228          0.241823
# 2321                   0.0         -0.771606         -0.624815
# 2322                   1.0         -1.211975          -0.49946
# 2323                   1.0         -0.124186         -0.901719
# ...                    ...               ...               ...
# 6032                  None              None              None
# 6033                  None              None              None
# 6034                  None              None              None
# 6035                  None              None              None
# 6036                  None              None              None
#
# 0    ns1:StandardDeviationPrice ns1:ClientDistributionBucket  \
# 2319                   4.045059                          3.0
# 2320                  10.442157                          3.0
# 2321                   9.872032                          4.0
# 2322                  22.142411                          4.0
# 2323                   21.90112                          4.0
# ...                         ...                          ...
# 6032                       None                         None
# 6033                       None                         None
# 6034                       None                         None
# 6035                       None                         None
# 6036                       None                         None
#
# 0    ns1:Percentile10Price ns1:Percentile90Price ns1:InstrumentType2  \
# 2319              -1.48533                  10.0             Forward
# 2320                -15.57              22.87903             Forward
# 2321                -15.68                 14.25             Forward
# 2322            -32.886059              28.07477             Forward
# 2323               -39.078               34.9035             Forward
# ...                    ...                   ...                 ...
# 6032                  None                  None                None
# 6033                  None                  None                None
# 6034                  None                  None                None
# 6035                  None                  None                None
# 6036                  None                  None                None
#
# 0                                         ns1:copyright
# 2319  This document, its contents, the data format a...
# 2320  This document, its contents, the data format a...
# 2321  This document, its contents, the data format a...
# 2322  This document, its contents, the data format a...
# 2323  This document, its contents, the data format a...
# ...                                                 ...
# 6032  This document, its contents, the data format a...
# 6033  This document, its contents, the data format a...
# 6034  This document, its contents, the data format a...
# 6035  This document, its contents, the data format a...
# 6036  This document, its contents, the data format a...
#
# [63190 rows x 46 columns]

# %%
markit_consensus.to_csv(r"C:\Users\rmolli\Desktop\Power-Europe\Data Mark-It Raw 07.csv", index = False)

# %%
os.getcwd()
# Out:
# 'c:\\Users\\rmolli\\Desktop\\Power-Europe\\Notebooks - std'
